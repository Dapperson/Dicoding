# %%
#Numbers
a = 10
print(a, "bertipe", type(a))
b = 1.7
print(b, "bertipe", type(b))
c = 1+2j
print(c, " Bertipe bilangan kompleks? ", isinstance(1+2j,complex))
# Out:
# 10 bertipe <class 'int'>
# 1.7 bertipe <class 'float'>
# (1+2j)  Bertipe bilangan kompleks?  True

# %%
x=[0]*10005;              #inisialisasi array 0 sebanyak 10005; x[0]=0
x[1]=1;                   #x[1]=1
 
for j in range(2,10001):
      x[j]=x[j-1]+x[j-2]  # Fibonacci
print(x[10000])
# Out:
# ...

# %%
b = 0.1234567890123456789
print(b)
# Out:
# 0.12345678901234568

# %%
a = 1234567890123456789
print(a)
# Out:
# 1234567890123456789

# %%
c = 1+5j
print(c)
# Out:
# (1+5j)

# %%
#Numbers
s = "Ini adalah string baris tunggal"
print(s)
# Out:
# Ini adalah string baris tunggal

# %%
s = '''Ini adalah string
yang memiliki baris pertama
dan selanjutnya baris kedua'''
print(s)
# Out:
# Ini adalah string
# yang memiliki baris pertama
# dan selanjutnya baris kedua

# %%
#List
x = [5,10,15,20,25,30,35,40]
print(x[5])
print(x[-1])
print(x[3:5])
print(x[:5])
print(x[-3:])
print(x[1:7:2])
# Out:
# 30
# 40
# [20, 25]
# [5, 10, 15, 20, 25]
# [30, 35, 40]
# [10, 20, 30]

# %%
x = [1,2,3]
x[2]=4
print(x)
# Out:
# [1, 2, 4]

# %%
x = [1,2,3]
x[2]=4
x.append(5)
print(x)
# Out:
# [1, 2, 4, 5]

# %%
binatang = ['kucing', 'rusa', 'badak', 'gajah']
del binatang[2]
print(binatang)
# Out:
# ['kucing', 'rusa', 'gajah']

# %%
del binatang[2]
print(binatang)
# Out:
# ['kucing', 'rusa']

# %%
s = "Hello World!"
print(s[4]) 		#ambil karakter kelima dari string s
print(s[6:11]) 		#ambil karakter ketujuh hingga sebelas dari string s
s[5]="d" 		#ubah karakter keenam dari string s menjadi "d", seharusnya gagal karena immutable
s = "Halo Dunia!"	#ubah isi string s menjadi "Halo Dunia!", seharusnya berhasil karena mutable
print(s)
# Out:
# o
# World
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-92d4851781d4> in <module>()
#       2 print(s[4])             #ambil karakter kelima dari string s
#       3 print(s[6:11])          #ambil karakter ketujuh hingga sebelas dari string s
# ----> 4 s[5]="d"                #ubah karakter keenam dari string s menjadi "d", seharusnya gagal karena immutable
#       5 s = "Halo Dunia!"       #ubah isi string s menjadi "Halo Dunia!", seharusnya berhasil karena mutable
#       6 print(s)
#
# TypeError: 'str' object does not support item assignment

# %%
#Tuple
t = (5,'program', 1+3j)
print(t[1])
print(t[0:3])
print(t[0]=10)
# Out:
#   File "<ipython-input-16-ecb370837c1e>", line 4
#     print(t[0]=10)
#          ^
# SyntaxError: keyword can't be an expression

# %%
#Set
a = {1,2,2,3,3,3}
print(a)
# Out:
# {1, 2, 3}

# %%
a = {1,2,3}
print(a[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-3732f14f209e> in <module>()
#       1 a = {1,2,3}
# ----> 2 print(a[1])
#
# TypeError: 'set' object is not subscriptable

# %%
#Dictionary
d = {1:'value','key':2}
print(type(d))
print("d[1] = ", d[1]);
print("d['key'] = ", d['key']);
# Out:
# <class 'dict'>
# d[1] =  value
# d['key'] =  2

# %%
d = {1:'value','key':2}
print(type(d))
print("d[1] = ", d[1]);
print("d['key'] = ", d['key']);
 
# Generates error
print("d[2] = ", d[2]);
# Out:
# <class 'dict'>
# d[1] =  value
# d['key'] =  2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-f32bffb27244> in <module>()
#       5
#       6 # Generates error
# ----> 7 print("d[2] = ", d[2]);
#
# KeyError: 2

# %%
#Konversi

# %%
print(float(5))
# Out:
# 5.0

# %%
print(int(10.6))
# Out:
# 10

# %%
print(int(-10.6))
# Out:
# -10

# %%
print(float('2.5'))
# Out:
# 2.5

# %%
print(str(25))
# Out:
# 25

# %%
print(int('1p'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-81ba9501c79e> in <module>()
# ----> 1 print(int('1p'))
#
# ValueError: invalid literal for int() with base 10: '1p'

# %%
print(set([1,2,3]))
# Out:
# {1, 2, 3}

# %%
print(tuple({5,6,7}))
# Out:
# (5, 6, 7)

# %%
print(list('hello'))
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
print(dict([[1,2],[3,4]]))
# Out:
# {1: 2, 3: 4}

# %%
print(dict([(3,26),(4,44)]))
# Out:
# {3: 26, 4: 44}
