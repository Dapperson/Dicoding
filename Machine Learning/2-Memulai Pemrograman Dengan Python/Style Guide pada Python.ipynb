# %%
pycodestyle kal.py
kal.py:5:5: E301 expected 1 blank line, found 0
kal.py:7:5: E112 expected an indented block
# Out:
#   File "<ipython-input-1-85ef1a89083a>", line 1
#     pycodestyle kal.py
#                   ^
# SyntaxError: invalid syntax
