# %%
#Fungsi

# %%
#Mendefinisikan fungsi
def nama_fungsi( parameter )
# Out:
#   File "<ipython-input-1-77197340896e>", line 2
#     def nama_fungsi( parameter )
#                                 ^
# SyntaxError: invalid syntax

# %%
def nama_fungsi( parameter ):
    "dokumentasi fungsi"
    statemen atau kode fungsi
   return [expression]
# Out:
#   File "<ipython-input-2-d0511b8985a1>", line 3
#     statemen atau kode fungsi
#                 ^
# SyntaxError: invalid syntax

# %%
def cetak( param1 ):
   print(param1)
   return

# %%
def cetak( param1 ):
    print(param1)

# %%
#Memanggil fugsi
def cetak(param1):
    print(param1)
    return
 
#panggil
cetak("Panggilan Pertama")
cetak("Panggilan Kedua")
# Out:
# Panggilan Pertama
# Panggilan Kedua

# %%
#Return
return None
# Out:
#   File "<ipython-input-6-72b239ffb0ff>", line 2
#     return None
#                ^
# SyntaxError: 'return' outside function

# %%
def kali(angka1, angka2):
    # Kalikan kedua parameter
    hasil = angka1 * angka2
    print('Dicetak dari dalam fungsi: {}'.format(hasil))
    return hasil
 
# Panggil fungsi kali
keluaran = kali(10, 20);
print('Dicetak sebagai kembalian: {}'.format(keluaran))
# Out:
# Dicetak dari dalam fungsi: 200
# Dicetak sebagai kembalian: 200

# %%
def kuadrat(x):
    return x*x
a = 10
k = kuadrat(a)
print('nilai kuadrat dari {} adalah {}'.format(a, k))
# Out:
# nilai kuadrat dari 10 adalah 100

# %%
#Pass by reference vs value
def ubah(list_saya):
    list_saya.append([1, 2, 3, 4])
    print('Nilai di dalam fungsi: {}'.format(list_saya))
 
# Panggil fungsi ubah
list_saya = [10, 20, 30]
ubah(list_saya)
print('Nilai di luar fungsi: {}'.format(list_saya))
# Out:
# Nilai di dalam fungsi: [10, 20, 30, [1, 2, 3, 4]]
# Nilai di luar fungsi: [10, 20, 30, [1, 2, 3, 4]]

# %%
def ubah(list_saya):
    "Deklarasi Variabel list_saya berikut hanya dikenali (berlaku) di dalam fungsi ubah"
    list_saya = [1, 2, 3, 4] 
    print ('Nilai di dalam fungsi: {}'.format(list_saya))
 
# Panggil fungsi ubah
list_saya = [10, 20, 30]
ubah(list_saya)
print('Nilai di luar fungsi: {}'.format(list_saya))
# Out:
# Nilai di dalam fungsi: [1, 2, 3, 4]
# Nilai di luar fungsi: [10, 20, 30]

# %%
#Argumen dan Parameter Fungsi
def fungsi_saya (a, b, c):
    #lakukansesuatudenganabc
# Out:
#   File "<ipython-input-11-48c0b3f00756>", line 3
#     #lakukansesuatudenganabc
#                             ^
# SyntaxError: unexpected EOF while parsing

# %%
fungsi_saya (1, b=14, c='Dicoding')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-fbe0e1948131> in <module>()
# ----> 1 fungsi_saya (1, b=14, c='Dicoding')
#
# NameError: name 'fungsi_saya' is not defined

# %%
#Argumen & Parameter
daftar(tanggal=1, bulan='Januari', tahun=2020)
daftar(**{'tanggal': 1, 'bulan': 'Januari', 'tahun': 2020})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a3ed28c358a3> in <module>()
#       1 #Argumen & Parameter
# ----> 2 daftar(tanggal=1, bulan='Januari', tahun=2020)
#       3 daftar(**{'tanggal': 1, 'bulan': 'Januari', 'tahun': 2020})
#
# NameError: name 'daftar' is not defined

# %%
daftar(1,'Januari',2020)
daftar(*(1, 'Januari', 2020))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-0cd42dc5bd9f> in <module>()
# ----> 1 daftar(1,'Januari',2020)
#       2 daftar(*(1, 'Januari', 2020))
#
# NameError: name 'daftar' is not defined

# %%
def kali(nilai1, nilai2=None): ...

# %%
def (nilai1, nilai2, /, nilai3): ...

# %%
def func(arg, *, kw_only1, kw_only2): ...

# %%
def func(*args, **kwargs): ...

# %%
def printinfo(*args, **kwargs):
    for a in args:
        print('argumen posisi {}'.format(a))
    for key, value in kwargs.items():
        print('argumen kata kunci {}:{}'.format(key, value))
 
 
# Panggil printinfo
printinfo()
printinfo(1, 2, 3)
printinfo(i=7, j=8, k=9)
printinfo(1, 2, j=8, k=9)
printinfo(*(2, 3), **{'i':7, 'j':8})
# Out:
# argumen posisi 1
# argumen posisi 2
# argumen posisi 3
# argumen kata kunci i:7
# argumen kata kunci j:8
# argumen kata kunci k:9
# argumen posisi 1
# argumen posisi 2
# argumen kata kunci j:8
# argumen kata kunci k:9
# argumen posisi 2
# argumen posisi 3
# argumen kata kunci i:7
# argumen kata kunci j:8

# %%
#Fungsi Anonim
lambda [arg1 [,arg2,.....argn]]:expression

# %%
kali = lambda nilai1, nilai2: nilai1 * nilai2
print ("Hasil : ", kali( 11, 21 ))
print ("Hasil : ", kali( 2, 2 ))
# Out:
# Hasil :  231
# Hasil :  4

# %%
#Menulis Modul dan Kelas pada Python

# %%
#Menulis modul
# Define a function
def world():
    print("Hello, World!")

# %%
#impor
import hello
#panggil
hello.world()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-96eeb163dc3a> in <module>()
#       1 #impor
# ----> 2 import hello
#       3 #panggil
#       4 hello.world()
#
# ModuleNotFoundError: No module named 'hello'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Menambahkan variable
def world():
    print("Hello, World!")
nama = "Dicoding"

# %%
#impor
import hello
 
#panggil
hello.world()
#cetak
print(hello.nama)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-21fceecb8ae0> in <module>()
#       1 #impor
# ----> 2 import hello.py
#       3
#       4 #panggil
#       5 hello.world()
#
# ModuleNotFoundError: No module named 'hello'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Menambahkan Kelas
def world():
    print("Hello, World!")
nama = "Dicoding"
class Reviewer:
    def __init__(self, nama, kelas):
        self.nama = nama
        self.kelas = kelas
    def review(self):
        print("Reviewer " + self.nama + " bertanggung jawab di kelas " + self.kelas)

# %%
#impor
import hello
#panggil
hello.world()
#cetak
print(hello.nama)
#review
diko = hello.Reviewer("Diko", "Python")
diko.review()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-d84935b62ca2> in <module>()
#       1 #impor
# ----> 2 import hello
#       3 #panggil
#       4 hello.world()
#       5 #cetak
#
# ModuleNotFoundError: No module named 'hello'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Implementasi kode
# Definisi
def world():
    print("Hello, World!")
# Panggil disini
world()

# %%
import hello2

# %%
#Mengakses modul dari folder lain

# %%
#Menambahkan path folder
import sys
sys.path.append('/home/dicoding')
import hello
…

# %%
#Menambahkan modul pada python path
print(sys.path)

# %%
import hello
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-f81fb083bdeb> in <module>()
# ----> 1 import hello
#
# ModuleNotFoundError: No module named 'hello'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
